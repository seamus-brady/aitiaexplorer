# %%
import os
import sys
import tempfile
import operator
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt 
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
from sklearn import mixture
from sklearn.model_selection import train_test_split

module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from aitia_explorer.app import App

# stop the warning clutter
import warnings
warnings.filterwarnings('ignore')

# %%
aitia = App()

# %%
df = aitia.data.hepar2_10k_data()

# %%
fp = tempfile.NamedTemporaryFile(suffix='.csv')
df.to_csv(fp.name, encoding='utf-8', index=False)
fp.name
# Out:
# '/tmp/tmp9psb0qm_.csv'

# %%
learner = gum.BNLearner(fp.name)
learner.useGreedyHillClimbing()
bn = learner.learnBN()
bn
# Out:
# (gum::BayesNet<double>@0x5615fb6cb420) BN{nodes: 70, arcs: 99, domainSize: 10^24.6392, dim: 702}

# %%
test_nx = aitia.graph_util.get_nxgraph_from_dot(bn.toDot())
test_nx = nx.DiGraph(test_nx)

# %%
target_nx = aitia.graph_util.get_nxgraph_from_dot(bn.toDot()) aitia.data.hepar2_graph()
target_nx = nx.DiGraph(target_nx)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/bin/anaconda3/envs/CAUSAL1/lib/python3.7/site-packages/networkx/convert.py in to_networkx_graph(data, create_using, multigraph_input)
#     155             try:
# --> 156                 return nx.from_scipy_sparse_matrix(data, create_using=create_using)
#     157             except:
#
# ~/bin/anaconda3/envs/CAUSAL1/lib/python3.7/site-packages/networkx/convert_matrix.py in from_scipy_sparse_matrix(A, parallel_edges, create_using, edge_attribute)
#     926     G = nx.empty_graph(0, create_using)
# --> 927     n, m = A.shape
#     928     if n != m:
#
# AttributeError: 'str' object has no attribute 'shape'
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-29-bbe093725551> in <module>
# ...

# %%
aitia.graph_metrics.SHD(target_nx, test_nx)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-2dacbc55fa84> in <module>
# ----> 1 aitia.graph_metrics.SHD(target_nx, test_nx)
#
# ~/GitHub/aitiaexplorer/src/aitia_explorer/metrics/graph_metrics.py in SHD(self, target, pred, double_for_anticausal)
#     108             SHD(tar, pred, double_for_anticausal=False)
#     109         """
# --> 110         true_labels = self.retrieve_adjacency_matrix(target)
#     111         predictions = self.retrieve_adjacency_matrix(pred, target.nodes()
#     112         if isinstance(target, nx.DiGraph) else None)
#
# ~/GitHub/aitiaexplorer/src/aitia_explorer/metrics/graph_metrics.py in retrieve_adjacency_matrix(self, graph, order_nodes, weight)
#      32                 return np.array(nx.adjacency_matrix(graph, order_nodes).todense())
#      33         else:
# ...

# %%
import networkx.algorithms.dag as dag
dag.dag_longest_path(test_nx2)
