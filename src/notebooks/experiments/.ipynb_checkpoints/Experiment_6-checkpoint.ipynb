# %%
# %run CommonCodeForExperiments.ipynb

# %%
import dowhy
from dowhy import CausalModel
import pandas as pd
import numpy as np
aitia = App()

# %%
random_scm1 = aitia.data.random_scm1()
random_scm1.cgm.draw()

# %%
df = random_scm1.sample(2000)

# %%
nx.write_gml(random_scm1.cgm.dag, "./random1.gml")

# %%
# Create a causal model from the data and given common causes.
xs = ""
for i in range(1,20):
    xs += ("x"+str(i)+"+")
model=CausalModel(
        data = df,
        graph="./random1.gml",
        treatment='X12',
        outcome='X18',
        common_causes=xs.split('+'))
# Out:
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['X12'] on outcome ['X18']

# %%
#Identify the causal effect
identified_estimand = model.identify_effect()
# Out:
# INFO:dowhy.causal_identifier:Common causes of treatment and outcome:['U']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n] y
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:['X6', 'X5']

# %%
# Estimate the causal effect and compare it with Average Treatment Effect
estimate = model.estimate_effect(identified_estimand,
        method_name="backdoor.linear_regression", test_significance=True
)

print(estimate)

print("Causal Estimate is " + str(estimate.value))
data_1 = data[data["treatment"]==1]
data_0 = data[data["treatment"]==0]

print("ATE", np.mean(data_1["y_factual"])- np.mean(data_0["y_factual"]))
# Out:
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# INFO:dowhy.causal_estimator:b: y_factual~treatment+x4+x7+x18+x16+x19+x8+x21+x1+x17+x11+x12+x14+x13+x10+x5+x15+x2+x3+x6+x22+x25+x23+x24+x20+x9
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              y_factual   R-squared:                       0.740
# Model:                            OLS   Adj. R-squared:                  0.731
# Method:                 Least Squares   F-statistic:                     78.91
# Date:                Fri, 26 Jun 2020   Prob (F-statistic):          6.10e-191
# Time:                        09:21:36   Log-Likelihood:                -1138.1
# No. Observations:                 747   AIC:                             2330.
# Df Residuals:                     720   BIC:                             2455.
# Df Model:                          26
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.1492      0.455     13.520      0.000       5.256       7.042
# x1            -3.9287      0.113    -34.823      0.000      -4.150      -3.707
# x2             0.2573      0.076      3.371      0.001       0.107       0.407
# x3            -0.0769      0.086     -0.896      0.371      -0.246       0.092
# x4             0.0903      0.231      0.392      0.695      -0.362       0.543
# x5            -0.3409      0.223     -1.530      0.126      -0.778       0.096
# x6             0.1057      0.165      0.642      0.521      -0.217       0.429
# x7             0.2195      0.149      1.471      0.142      -0.074       0.513
# x8             0.0105      0.158      0.067      0.947      -0.300       0.321
# x9             0.0083      0.093      0.089      0.929      -0.174       0.191
# x10            0.0149      0.095      0.156      0.876      -0.172       0.202
# x11           -0.0878      0.158     -0.557      0.578      -0.398       0.222
# x12            0.0701      0.149      0.469      0.639      -0.223       0.363
# x13            0.1626      0.149      1.094      0.274      -0.129       0.454
# x14           -0.0724      0.094     -0.773      0.440      -0.256       0.111
# x15            0.1497      0.171      0.875      0.382      -0.186       0.486
# x16            0.0113      0.046      0.247      0.805      -0.078       0.101
# x17            1.0107      0.127      7.928      0.000       0.760       1.261
# x18           -0.0403      0.084     -0.478      0.633      -0.206       0.125
# x19           -0.0035      0.071     -0.049      0.961      -0.143       0.136
# x20            0.9004      0.058     15.596      0.000       0.787       1.014
# x21           -0.0235      0.199     -0.118      0.906      -0.414       0.367
# x22           -0.0517      0.159     -0.324      0.746      -0.365       0.261
# x23            0.0819      0.201      0.408      0.683      -0.312       0.476
# x24            0.3706      0.177      2.090      0.037       0.022       0.719
# x25            0.3402      0.169      2.009      0.045       0.008       0.673
# x26           -0.0912      0.100     -0.908      0.364      -0.288       0.106
# ==============================================================================
# Omnibus:                       17.787   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.252
# Skew:                           0.258   Prob(JB):                     8.93e-06
# Kurtosis:                       3.694   Cond. No.                         33.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: nonparametric-ate
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#      d
# ────────────(Expectation(y_factual|x4,x7,x18,x16,x19,x8,x21,x1,x17,x11,x12,x14
# d[treatment]
#
#
# ,x13,x10,x5,x15,x2,x3,x6,x22,x25,x23,x24,x20,x9))
#
# Estimand assumption 1, Unconfoundedness: If U→{treatment} and U→y_factual then P(y_factual|treatment,x4,x7,x18,x16,x19,x8,x21,x1,x17,x11,x12,x14,x13,x10,x5,x15,x2,x3,x6,x22,x25,x23,x24,x20,x9,U) = P(y_factual|treatment,x4,x7,x18,x16,x19,x8,x21,x1,x17,x11,x12,x14,x13,x10,x5,x15,x2,x3,x6,x22,x25,x23,x24,x20,x9)
# ### Estimand : 2
# Estimand name: iv
# No such variable found!
#
# ## Realized estimand
# b: y_factual~treatment+x4+x7+x18+x16+x19+x8+x21+x1+x17+x11+x12+x14+x13+x10+x5+x15+x2+x3+x6+x22+x25+x23+x24+x20+x9
# Target units: ate
#
# ## Estimate
# Mean value: -3.928671750872708
# p-value: [1.58915682e-156]
#
# Causal Estimate is -3.928671750872708
# ATE -4.021121012430829

# %%
data = data.drop(['mu0', 'x1', 'x16', 'x20'], axis=1)

# %%
# Create a causal model from the data and given common causes.
xs = ""
for i in range(1,26):
    xs += ("x"+str(i)+"+")
model=CausalModel(
        data = data,
        treatment='treatment',
        outcome='y_factual',
        common_causes=xs.split('+')
        )
# Out:
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['treatment'] on outcome ['y_factual']

# %%
#Identify the causal effect
identified_estimand = model.identify_effect()
print(identified_estimand)
# Out:
# INFO:dowhy.causal_identifier:Common causes of treatment and outcome:['U']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n] y
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:['X6', 'X5']
# Estimand type: nonparametric-ate
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#   d
# ──────(Expectation(X18))
# d[X₁₂]
# Estimand assumption 1, Unconfoundedness: If U→{X12} and U→X18 then P(X18|X12,,U) = P(X18|X12,)
# ### Estimand : 2
# Estimand name: iv
# Estimand expression:
# Expectation(Derivative(X18, [X6, X5])*Derivative([X12], [X6, X5])**(-1))
# Estimand assumption 1, As-if-random: If U→→X18 then ¬(U →→{X6,X5})
# Estimand assumption 2, Exclusion: If we remove {X6,X5}→{X12}, then ¬({X6,X5}→X18)

# %%
causal_estimate = model.estimate_effect(identified_estimand,
        method_name="backdoor.propensity_score_stratification")
print(causal_estimate)
print("Causal Estimate is " + str(causal_estimate.value))
# Out:
# ERROR:dowhy.causal_estimator:Propensity score methods are applicable only for binary treatments
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-24-72a5255255ef> in <module>
#       1 causal_estimate = model.estimate_effect(identified_estimand,
# ----> 2         method_name="backdoor.propensity_score_stratification")
#       3 print(causal_estimate)
#       4 print("Causal Estimate is " + str(causal_estimate.value))
#
# ~/bin/anaconda3/envs/CAUSAL1/lib/python3.7/site-packages/dowhy/causal_model.py in estimate_effect(self, identified_estimand, method_name, control_value, treatment_value, test_significance, evaluate_effect_strength, confidence_intervals, target_units, effect_modifiers, method_params)
#     228                 target_units = target_units,
#     229                 effect_modifiers = effect_modifiers,
# --> 230                 params=method_params
#     231             )
#     232             estimate = causal_estimator.estimate_effect()
#
# ~/bin/anaconda3/envs/CAUSAL1/lib/python3.7/site-packages/dowhy/causal_estimators/propensity_score_stratification_estimator.py in __init__(self, num_strata, clipping_threshold, *args, **kwargs)
#      14
#      15     def __init__(self, *args, num_strata=50, clipping_threshold=10, **kwargs):
# ---> 16         super().__init__(*args,  **kwargs)
#      17
#      18         self.logger.info("INFO: Using Propensity Score Stratification Estimator")
#
# ~/bin/anaconda3/envs/CAUSAL1/lib/python3.7/site-packages/dowhy/causal_estimators/propensity_score_estimator.py in __init__(self, *args, **kwargs)
#      19             error_msg = "Propensity score methods are applicable only for binary treatments"
#      20             self.logger.error(error_msg)
# ---> 21             raise Exception(error_msg)
#      22
#      23         self.logger.debug("Back-door variables used:" +
#
# Exception: Propensity score methods are applicable only for binary treatments
