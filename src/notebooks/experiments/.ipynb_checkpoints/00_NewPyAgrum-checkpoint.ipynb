# %%
import os
import sys
import tempfile
import operator
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt 
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
import pyAgrum.causal as csl
import pyAgrum.causal.notebook as cslnb
from sklearn import mixture
from sklearn.model_selection import train_test_split

module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from aitia_explorer.app import App

# stop the warning clutter
import warnings
warnings.filterwarnings('ignore')

# %%
aitia = App()

# %%
df = aitia.data.hepar2_10k_data()

# %%
fp = tempfile.NamedTemporaryFile(suffix='.csv')
df.to_csv(fp.name, encoding='utf-8', index=False)
fp.name
# Out:
# '/tmp/tmp9psb0qm_.csv'

# %%
learner = gum.BNLearner(fp.name)
learner.useGreedyHillClimbing()
bn = learner.learnBN()
bn
# Out:
# (gum::BayesNet<double>@0x5615fb6cb420) BN{nodes: 70, arcs: 99, domainSize: 10^24.6392, dim: 702}

# %%
test_nx = aitia.graph_util.get_nxgraph_from_dot(bn.toDot())

# %%
target_nx = aitia.graph_util.get_nxgraph_from_dot(aitia.data.hepar2_graph())

# %%
aitia.graph_metrics.SHD(target_nx, test_nx)
# Out:
# 72

# %%
bn.sizeArcs()
# Out:
# 99

# %%
ie=gum.LazyPropagation(bn)
ie.makeInference()

# %%
jt=ie.junctionTree()
gnb.showJunctionTree(bn,size="20")

# %%
df2 = df.drop(['fat', 'surgery', 'gallstones'], axis=1)

# %%
fp = tempfile.NamedTemporaryFile(suffix='.csv')
df2.to_csv(fp.name, encoding='utf-8', index=False)
learner = gum.BNLearner(fp.name)
learner.useMIIC()
bn2 = learner.learnBN()

# %%
gnb.sideBySide(bn2,
               [(bn2.variable(i).name(), bn2.variable(j).name()) for (i,j) in learner.latentVariables()],
               captions=['learned model', 'Latent variables found'])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="111pt" viewBox="0.00 0.00 360.00 110.68" width="360pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(.1324 .1324) rotate(0) translate(4 832)">
# <title>G</title>
# <!-- alcoholism -->
# <g class="node" id="node1">
# <title>alcoholism</title>
# <g id="a_node1"><a xlink:title="(0) alcoholism">
# <ellipse cx="942.2401" cy="-522" fill="#404040" rx="50.0912" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="942.2401" y="-518.3">alcoholism</text>
# </a>
# </g>
# </g>
# <!-- THepatitis -->
# <g class="node" id="node4">
# <title>THepatitis</title>
# <g id="a_node4"><a xlink:title="(3) THepatitis">
# ...
