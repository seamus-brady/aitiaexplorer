# %% [markdown]
# # Experiment 1

# %% [markdown]
# ### Include the common code notebook

# %%
# %run CommonCodeForExperiments.ipynb

# %%
aitia = App()

# %%
pc = pycausal()
pc.start_vm()

# %%
virus_scm = aitia.data.virus_scm()
virus_scm.cgm.draw()

# %%
target_graph_str = str(virus_scm.cgm.draw())

# %%
df = virus_scm.sample(2000)
df
# Out:
#        smoking  blood_pressure    gene_3    gene_2    gene_1       bmi  \
# 0    -0.044566        1.183780  0.491421  0.155188  0.472630  0.567950
# 1    -2.270672        0.378909 -0.551992 -0.411765  1.491631  0.142117
# 2    -1.831853        2.276885  0.981292 -2.194341  1.423492 -0.277867
# 3     0.415017        0.361071  0.481933  0.294547 -0.119089 -1.046865
# 4     0.321555       -0.395583 -1.578266  0.117909  0.756280 -1.464007
# ...        ...             ...       ...       ...       ...       ...
# 1995 -1.271355       -0.416186 -0.424615  0.845120  0.068725  0.280820
# 1996 -0.503481       -1.086463 -0.391293  0.178272 -0.115752 -0.649732
# 1997 -0.673121        0.768236 -0.565930  0.877889  0.483913  0.777278
# 1998  0.026514       -0.939997  0.093440 -0.338696  0.340932  0.692055
# 1999  0.942156       -0.670445 -0.948786  0.314430  0.981598  0.244635
#
#       white_cell_count       age  heart_health  serious_viral_illness  \
# 0             0.516885 -0.931142     -0.572428               0.700866
# 1            -2.267890 -1.024360     -0.617488              -1.418453
# 2            -1.810902 -0.775283      1.296277              -3.015232
# 3            -1.680557  0.031202     -1.108327              -1.256999
# 4            -1.510824 -0.633813     -1.613299              -0.520108
# ...                ...       ...           ...                    ...
# 1995          0.081342 -0.396118      0.882957               2.118982
# 1996          0.338628 -1.713550     -2.380156              -0.083349
# 1997         -0.235029 -0.666175     -1.397475              -1.023288
# 1998          1.631098  0.085721     -1.076723               2.342139
# 1999         -1.552762 -1.498185     -2.305971              -1.170946
#
#         gene_4    gene_5    gene_6    gene_7
# 0     0.029978 -0.138382  0.535102 -0.640861
# 1     1.264630  1.094791 -1.007506  2.846085
# 2     0.367172  0.820582  0.051507 -2.054321
# 3    -0.703798  0.317677  0.666241 -1.605587
# 4     0.597559  1.568970  0.674681 -1.616146
# ...        ...       ...       ...       ...
# 1995  0.332379 -0.104401 -0.597325  0.496090
# 1996 -0.269075 -0.162755  0.869993  0.032122
# 1997  1.647621  1.863750  0.689255  0.793371
# 1998  0.987738 -0.958234 -0.436578  0.764488
# 1999  0.416852  1.771742  1.829186 -0.290873
#
# [2000 rows x 14 columns]

# %%
analysis_results, summary = aitia.run_analysis(df, 
                                               target_graph_str=target_graph_str, 
                                               algorithm_list=[
                                                   aitia.algo_runner.PC,
                                                   aitia.algo_runner.FCI,
                                                   aitia.algo_runner.FGES_continuous,
                                                   aitia.algo_runner.GFCI_continuous,
                                                   aitia.algo_runner.RFCI_continuous,
                                               ],
                                               pc=pc)
summary
# Out:
#          Algorithm Isomorphic to Target?      AURC SHD
# 0               PC                 False  0.935884   2
# 1              FCI                 False  0.935884   2
# 2  FGES-continuous                 False  0.935884   2
# 3  GFCI-continuous                 False  0.935884   2
# 4  RFCI-continuous                 False  0.935884   2

# %%
df2 = df.drop(['white_cell_count'], axis=1)

# %%
min_clusters = 2
max_clusters = 5

# %%
bics, bics_err = get_bic_scores(min_clusters, max_clusters, df2)

# %%
plot_bic_aic_scores(bics, bics_err, min_clusters, max_clusters)

# %%
plot_bic_gradient(bics, bics_err, min_clusters, max_clusters)

# %%
tt_results, tt_res_sigs = get_train_test_distance(min_clusters, max_clusters, df2)

# %%
sils, sils_err= get_silhouette_coefficient(min_clusters, max_clusters, df)
