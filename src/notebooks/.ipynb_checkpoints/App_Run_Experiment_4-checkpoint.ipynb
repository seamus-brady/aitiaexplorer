# %%
import os
import sys
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from aitia_explorer.py_causal_wrapper import PyCausalUtil 
from aitia_explorer.metrics.graph_metrics import GraphMetrics
from aitia_explorer.util.graph_util import GraphUtil
from aitia_explorer.target_data.loader import TargetData
from aitia_explorer.app import App
from pycausal.pycausal import pycausal

# stop the warning clutter
import warnings
warnings.filterwarnings('ignore')

# %%
lucas_data = TargetData.lucas2_data()
lucas_data
# Out:
#       Smoking  Yellow_Fingers  Anxiety  Peer_Pressure  Genetics  \
# 0           0               0        1              0         0
# 1           0               1        0              0         0
# 2           1               1        1              0         1
# 3           0               0        0              1         0
# 4           1               1        1              0         0
# ...       ...             ...      ...            ...       ...
# 1995        0               0        1              0         0
# 1996        1               1        1              0         0
# 1997        1               1        0              1         0
# 1998        1               1        1              0         1
# 1999        1               1        0              1         0
#
#       Attention_Disorder  Born_an_Even_Day  Car_Accident  Fatigue  Allergy  \
# 0                      1                 0             1        0        1
# 1                      0                 1             0        1        0
# 2                      1                 1             1        1        1
# 3                      0                 1             0        0        0
# 4                      1                 1             1        1        0
# ...                  ...               ...           ...      ...      ...
# 1995                   0                 0             1        1        0
# 1996                   0                 0             0        1        0
# 1997                   0                 1             0        1        0
# 1998                   1                 0             1        1        0
# 1999                   0                 0             0        1        1
#
#       Coughing  Lung_cancer
# 0            0            0
# 1            1            1
# 2            1            1
# 3            0            0
# 4            0            1
# ...        ...          ...
# 1995         1            1
# 1996         1            1
# 1997         0            1
# 1998         1            1
# 1999         1            1
#
# [2000 rows x 12 columns]

# %%
pc = pycausal()
pc.start_vm()

# %%
aitia_ex = App()

# %%
analysis_results, summary = aitia_ex.run_analysis(lucas_data, target_graph_str=None, pc=pc)
summary
# Out:
# Continuous Data: expect 12 variables but found 0.
# Continuous Data: expect 12 variables but found 0.
# Continuous Data: expect 12 variables but found 0.
# Continuous Data: expect 12 variables but found 0.
# Continuous Data: expect 12 variables but found 0.
# Continuous Data: expect 12 variables but found 0.
#          Algorithm Ind Relations Diff Isomorphic to Target? AURC SHD
# 0         BayesEst              11788                    NA    0   0
# 1              FCI              11788                    NA    0   0
# 2               PC              11788                    NA    0   0
# 3  FGES-continuous              11788                    NA    0   0
# 4    FGES-discrete              14692                    NA    0   0
# 5  GFCI-continuous              11788                    NA    0   0
# 6    GFCI-discrete              14692                    NA    0   0
# 7  RFCI-continuous              11788                    NA    0   0
# 8    RFCI-discrete              11788                    NA    0   0

# %%
analysis_results[8]['causal_graph'].draw()

# %%
X = lucas_data
from sklearn import mixture
gmm = mixture.GaussianMixture(n_components=4).fit(X)
labels = gmm.predict(X)
labels
# Out:
# array([0, 3, 2, ..., 3, 2, 2])

# %%
list(X)
# Out:
# ['Smoking',
#  'Yellow_Fingers',
#  'Anxiety',
#  'Peer_Pressure',
#  'Genetics',
#  'Attention_Disorder',
#  'Born_an_Even_Day',
#  'Car_Accident',
#  'Fatigue',
#  'Allergy',
#  'Coughing',
#  'Lung_cancer']

# %%
X.shape
# Out:
# (2000, 12)

# %%
data_new = gmm.sample(2000)
X_new = pd.DataFrame(data_new[0], columns=list(X))
X_new
# Out:
#        Smoking  Yellow_Fingers   Anxiety  Peer_Pressure  Genetics  \
# 0    -0.000028        0.250828 -0.083252       0.398326 -0.114713
# 1    -0.000110       -0.462878  0.938021      -0.123214 -0.420275
# 2    -0.002616        0.007689  0.594790      -0.191116  0.521103
# 3     0.000448       -0.392432  0.652290       0.699751  0.750258
# 4     0.001068        0.182516  0.619204       0.426644 -0.252129
# ...        ...             ...       ...            ...       ...
# 1995  1.415941        1.001042  1.216067       0.620537  0.270211
# 1996  0.701271        0.999856  0.310553      -0.262977 -0.328560
# 1997  0.841034        0.999588 -0.243237       0.596190  0.069278
# 1998  0.985485        0.998665  0.516040       0.366349  0.223981
# 1999  0.590779        0.998766  0.605667       0.200906 -0.119477
#
#       Attention_Disorder  Born_an_Even_Day  Car_Accident   Fatigue   Allergy  \
# 0               0.398240          0.589859      0.855314  0.695217 -0.108507
# 1               0.554286          1.038460      1.024404  0.614778 -0.291954
# 2               1.332814          0.581082      0.680478  0.467630  0.829687
# 3               0.218736          0.529035      0.922994  0.187765 -0.390665
# 4              -0.454424          1.130241      1.384907  0.703994 -0.211578
# ...                  ...               ...           ...       ...       ...
# 1995            0.000374          1.001002      0.338173  0.809204  0.347086
# 1996           -0.000525          1.001034      1.271758  0.793758  0.291413
# 1997           -0.000969          0.999652      0.665821  0.848681  0.322683
# 1998            0.000188          1.001196      0.082747  0.121148  0.190140
# 1999           -0.000252          0.999966      1.175282  0.593280  0.168579
#
#       Coughing  Lung_cancer
# 0     1.040662    -0.047653
# 1     1.152203     0.728627
# 2     1.025520     1.111052
# 3    -0.064115     0.598795
# 4    -0.204911    -0.029880
# ...        ...          ...
# 1995  1.079852     0.875077
# 1996  0.575624     0.792240
# 1997  0.998530     1.220338
# 1998  0.884262     1.004112
# 1999  0.293884     0.624011
#
# [2000 rows x 12 columns]

# %%
analysis_results2, summary2 = aitia_ex.run_analysis(X_new, target_graph_str=None, pc=pc)
summary2
