# %%
import os
import sys
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from pycausal.pycausal import pycausal

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from aitia_explorer.app import App

# stop the warning clutter
import warnings
warnings.filterwarnings('ignore')

# %%
pc = pycausal()
pc.start_vm()

# %%
aitia = App()

# %%
scm3 = aitia.data.scm3()
scm3.cgm.draw()

# %%
target_graph_str = str(scm3.cgm.draw())

# %%
df = scm3.sample(2000)
df
# Out:
#              l         k         m         e         d         c         b  n  \
# 0    -1.398501  0.051023 -0.689075  1.359502  1.520304  0.319326  1.688618  1
# 1     1.035543 -0.866934 -0.213498  0.372900 -1.064862  1.067967 -1.135793  1
# 2     0.673608  1.757443  1.802325 -1.086796  0.520088 -0.769060 -0.577600  0
# 3    -0.223591  0.025966  0.390842  1.216933 -0.207316  1.493090 -0.085254  1
# 4    -0.435354 -0.427559 -0.895876 -0.062409  1.657229  0.050404 -0.985801  1
# ...        ...       ...       ...       ...       ...       ...       ... ..
# 1995  0.477021  0.651381  1.142222 -0.861206  1.377958 -0.095780 -1.423065  0
# 1996 -1.050126  1.346679 -0.963138 -0.576527 -0.696500 -0.478309 -0.175500  0
# 1997  1.202310 -0.707809  0.667356 -1.516417 -1.306219  1.064454 -0.603399  0
# 1998  0.419926  0.410916  0.698155  0.531630 -1.571950 -0.447751 -1.395048  0
# 1999 -0.882290 -0.413016 -0.555287 -0.723760  0.822702 -0.530201 -0.492409  0
#
#       j  f         g         h         a  i
# 0     1  1  0.762883  1.095784  0.505377  1
# 1     0  0 -1.362938 -1.738727 -0.361189  0
# 2     1  1  2.108837  2.051682  0.348629  0
# 3     0  0 -0.905542  0.233139 -1.034531  1
# 4     0  0  3.635875  3.103628  2.950294  0
# ...  .. ..       ...       ...       ... ..
# 1995  0  0  1.600652  2.338487 -0.021409  0
# 1996  0  1 -0.913485 -2.361702 -1.084905  1
# 1997  1  0 -2.922943 -2.395212 -0.870047  1
# 1998  0  0 -2.808837 -3.049216 -1.325074  0
# 1999  0  0  1.998297  2.343968  0.068809  0
#
# [2000 rows x 14 columns]

# %%
analysis_results, summary = aitia.run_analysis(df, 
                                               target_graph_str=target_graph_str, 
                                               algorithm_list=[
                                                   aitia.algo_runner.PC,
                                                   aitia.algo_runner.FCI
                                               ],
                                               pc=pc)
summary
# Out:
#   Algorithm Isomorphic to Target?  AURC SHD
# 0        PC                 False   1.0   0
# 1       FCI                 False   1.0   0

# %%
analysis_results[0]['causal_graph'].draw()

# %%
X = df
from sklearn import mixture
gmm = mixture.BayesianGaussianMixture(n_components=1).fit(X)
labels = gmm.predict(X)

# %%
list(X)
# Out:
# ['f', 'h', 'g', 'e', 'b', 'a', 'c', 'd']

# %%
X.shape
# Out:
# (1000, 8)

# %%
data_new = gmm.sample(2000)
X_new = pd.DataFrame(data_new[0], columns=list(X))
X_new
# Out:
#              l         k         m         e         d         c         b  \
# 0     0.637310 -0.538546 -0.222010 -0.661111 -0.880589  1.085230 -0.619776
# 1     0.205101 -0.823250 -0.169838  0.488397  2.076816  0.697901  1.462282
# 2     1.740940  0.589507  2.759891  0.386002  1.347148  0.621596 -0.053276
# 3    -0.140295  1.564692 -1.191023  0.195915 -0.214877 -0.573281 -0.321470
# 4     0.880579 -0.960844  0.767394  0.795711 -0.179183 -0.750516 -0.579719
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995  0.302280  1.702750  2.631730  0.097820 -1.207947  1.658908 -1.061985
# 1996  1.109531  1.633465  2.043687  0.361329 -1.241164 -0.558839  0.146276
# 1997 -0.747183 -0.248032 -1.588503  1.822872  0.740133  2.311799  1.435414
# 1998  0.922824  1.103961  0.484235  0.356323 -0.976558  0.275983  0.317366
# 1999  0.761376  1.062956  1.805064  0.269761  0.496200  0.441616 -0.570095
#
#              n         j         f         g         h         a         i
# 0     0.433638  0.070593  0.649006 -0.700403 -2.413645  0.432452  0.574849
# 1     0.934304  0.411502  0.848967  2.721082  4.271049 -1.086039  1.290241
# 2    -0.037105  0.408059  0.124393  0.352677  0.334761 -0.008128  1.084479
# 3     0.516056  0.677683  0.079621 -2.336580 -1.842213 -1.194685  0.923552
# 4    -0.529845  0.376340  0.416874  0.109980 -0.423446 -1.808878  1.773724
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995  0.419526  0.170735 -0.404935 -1.290448 -1.431819 -0.903074  0.593385
# 1996 -0.684066  0.219258  0.063119 -0.974062  0.427598  0.611968  0.527092
# 1997  1.391576  0.312025  1.241675  1.078930  0.020542 -0.716302  1.234902
# 1998  1.065362  0.973408  0.786917  1.832300  0.502219  0.075152  0.592983
# 1999 -0.288193  0.095333  1.294612  0.511905  2.266362 -0.848597  0.224784
#
# [2000 rows x 14 columns]

# %%
analysis_results2, summary2 = aitia.run_analysis(X_new, 
                                               target_graph_str=target_graph_str, 
                                               algorithm_list=[
                                                   aitia.algo_runner.PC,
                                                   aitia.algo_runner.FCI
                                               ],
                                               pc=pc)
summary2
# Out:
#   Algorithm Isomorphic to Target?      AURC SHD
# 0        PC                 False  0.966667   1
# 1       FCI                 False  0.966667   1

# %%
analysis_results2[0]['causal_graph'].draw()
