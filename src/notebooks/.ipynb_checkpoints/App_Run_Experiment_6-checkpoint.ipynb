# %%
import os
import sys
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from pycausal.pycausal import pycausal

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from aitia_explorer.app import App

# stop the warning clutter
import warnings
warnings.filterwarnings('ignore')

# %%
pc = pycausal()
pc.start_vm()

# %%
aitia = App()

# %%
scm1 = aitia.data.scm1()
scm1.cgm.draw()

# %%
target_graph_str = str(scm1.cgm.draw())
target_graph_str
# Out:
# 'digraph {\n\tx [label=x shape=ellipse]\n\ta [label=a shape=ellipse]\n\tf [label=f shape=ellipse]\n\tb [label=b shape=ellipse]\n\th [label=h shape=ellipse]\n\td [label=d shape=ellipse]\n\te [label=e shape=ellipse]\n\ty [label=y shape=ellipse]\n\tc [label=c shape=ellipse]\n\ta -> x\n\ta -> h\n\tb -> x\n\tb -> d\n\tx -> c\n\tc -> y\n\ty -> f\n\ty -> h\n\td -> e\n\te -> y\n}'

# %%
df = scm1.sample(1000)
df
# Out:
#             b         d         e         a  x         c         y          h  \
# 0    0.690103 -2.094232 -3.371494 -1.470159  1  0.505619  5.536976   5.181346
# 1   -0.300310 -0.557669 -0.437269 -0.915088  1  1.124369  4.686109   5.005173
# 2   -1.073493  1.502230  2.415533  0.323410  1  1.301071  0.276917   1.446049
# 3    0.786186 -1.334497 -3.169765 -0.193036  0  1.645384  8.714108   9.594008
# 4    0.248916 -0.231050 -0.595930  1.457443  1  1.177453  3.450978   8.494505
# ..        ...       ...       ...       ... ..       ...       ...        ...
# 995 -0.496742  2.455983  4.550270 -0.661741  1 -0.466595 -4.587546  -7.326674
# 996 -0.144637  0.332679  1.483282  0.706611  1  0.829282  2.092614   3.399742
# 997  0.627185 -0.690722 -0.930263  1.669107  1  2.285692  6.413584  12.192055
# 998 -0.195813  2.152757  5.303336 -0.575188  1  0.556016 -4.210926  -7.411520
# 999  0.186699 -0.237251 -0.492502  1.178157  1  1.379896  4.917357   9.855611
#
#             f
# 0    4.326036
# 1    2.401123
# 2    1.079158
# 3    4.220441
# 4    2.827529
# ..        ...
# 995 -2.534945
# 996  1.025008
# 997  4.166199
# 998 -1.008985
# 999  2.883399
#
# [1000 rows x 9 columns]

# %%
analysis_results, summary = aitia.run_analysis(df, 
                                               target_graph_str=target_graph_str, 
                                               algorithm_list=[aitia.algo_runner.PC],
                                               pc=pc)
summary
# Out:
#   Algorithm Isomorphic to Target?      AURC SHD
# 0        PC                 False  0.718519   6

# %%
analysis_results[0]['causal_graph'].draw()

# %%
X = df
from sklearn import mixture
gmm = mixture.BayesianGaussianMixture(n_components=4).fit(X)
labels = gmm.predict(X)

# %%
list(X)
# Out:
# ['b', 'd', 'e', 'a', 'x', 'c', 'y', 'h', 'f']

# %%
X.shape
# Out:
# (1000, 9)

# %%
data_new = gmm.sample(200)
X_new = pd.DataFrame(data_new[0], columns=list(X))
X_new
# Out:
#             b         d         e         a         x         c         y  \
# 0   -0.281554  1.006796  2.367884  0.567276  0.628122 -0.772788 -4.384524
# 1   -0.316127  1.377710  1.864070 -1.054921  1.007993  0.426828 -1.097923
# 2   -0.946929  0.095474 -0.030558 -1.236955  1.030228  1.505271  4.431443
# 3    0.972165 -2.589535 -6.063432  0.195589  1.025156  0.358371  6.992562
# 4   -1.652328  0.509053  0.620630  0.833165  1.001445  1.487868  4.620198
# ..        ...       ...       ...       ...       ...       ...       ...
# 195 -0.275704 -0.895598 -2.413377 -1.066211 -0.043481 -0.763075  0.905845
# 196 -0.454680 -1.634605 -2.800893 -0.472654  0.018824  0.629145  5.025117
# 197 -0.541792  0.420628  0.519724  0.861469  0.030561 -0.488578 -3.382086
# 198  0.481075 -1.227404 -2.165711  0.951043 -0.003343  1.224100  7.157791
# 199 -0.818893  0.219016 -0.034890 -0.856744  0.000278 -0.996669 -2.026349
#
#              h         f
# 0    -6.365379 -3.624918
# 1    -3.283330 -1.910293
# 2     4.862767  2.044010
# 3     9.452652  5.193631
# 4     6.316549  4.684469
# ..         ...       ...
# 195  -1.796887  0.997535
# 196   5.469337  2.602695
# 197  -2.427902 -1.839541
# 198  10.193873  5.933129
# 199  -4.520830 -3.287549
#
# [200 rows x 9 columns]

# %%
analysis_results2, summary2 = aitia.run_analysis(df, 
                                               target_graph_str=target_graph_str, 
                                               algorithm_list=[aitia.algo_runner.PC],
                                               pc=pc)
summary2
# Out:
#   Algorithm Isomorphic to Target?      AURC SHD
# 0        PC                 False  0.718519   6

# %%
analysis_results[0]['causal_graph'].draw()
