# %%
import os
import sys
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from aitia_explorer.app import App

# stop the warning clutter
import warnings
warnings.filterwarnings('ignore')

aitia = App()

# %%
scm1 = aitia.data.scm1()
scm1.cgm.draw()

# %%
target_graph_str = str(scm1.cgm.draw())
target_graph_str
# Out:
# 'digraph {\n\tb [label=b shape=ellipse]\n\tf [label=f shape=ellipse]\n\tx [label=x shape=ellipse]\n\td [label=d shape=ellipse]\n\te [label=e shape=ellipse]\n\ta [label=a shape=ellipse]\n\ty [label=y shape=ellipse]\n\th [label=h shape=ellipse]\n\tc [label=c shape=ellipse]\n\ta -> x\n\ta -> h\n\tb -> x\n\tb -> d\n\tx -> c\n\tc -> y\n\ty -> f\n\ty -> h\n\td -> e\n\te -> y\n}'

# %%
df = scm1.sample(1000)
df
# Out:
#             b         d         e         a  x         c          y  \
# 0    0.985910 -1.511850 -3.079530 -1.265748  1  0.917252   5.470672
# 1   -1.347713  0.552452  1.912958 -0.280674  1 -0.722198  -4.011538
# 2   -0.399620  0.370224  1.406242  1.388034  0  0.659459   0.341441
# 3   -0.528248 -0.097385 -0.285394 -2.239757  0 -1.110516  -4.226830
# 4    0.558391 -0.056949 -0.014366 -0.603188  0  0.258488  -0.058084
# ..        ...       ...       ...       ... ..       ...        ...
# 995  1.877399 -1.142561 -2.841398  0.557203  1  2.496378  10.318991
# 996  0.245437 -0.836020 -1.952131  0.967453  0 -1.856113  -4.196043
# 997 -1.306184  0.340505 -0.277949 -2.125541  0 -1.562318  -4.694405
# 998 -0.263565 -0.559227 -0.057871 -0.682665  0  0.098975   1.601394
# 999  1.730487 -1.064362 -2.977382 -2.554729  1  2.438802   8.271795
#
#              h         f
# 0     3.912839  4.002139
# 1    -5.848964 -2.813066
# 2     3.219451 -1.286810
# 3   -11.072195 -2.980711
# 4    -1.830076  2.908487
# ..         ...       ...
# 995  16.065815  6.258415
# 996  -2.687406 -2.933617
# 997 -11.088649 -2.336780
# 998   1.363310  1.080884
# 999   5.818151  5.654025
#
# [1000 rows x 9 columns]

# %%
aitia.pc_util.pc.start_vm()

# %%
analysis_results, summary = aitia.run_analysis(df, 
                                               target_graph_str=target_graph_str, 
                                               algorithm_list=[aitia.algo_runner.PC],
                                               pc=aitia.pc_util.pc)
summary
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-975280b33ec4> in <module>
#       2                                                target_graph_str=target_graph_str,
#       3                                                algorithm_list=[aitia.algo_runner.PC],
# ----> 4                                                pc=aitia.pc_util.pc)
#       5 summary
#
# AttributeError: 'App' object has no attribute 'pc_util'

# %%
analysis_results[8]['causal_graph'].draw()

# %%
X = lucas_data
from sklearn import mixture
gmm = mixture.BayesianGaussianMixture(n_components=4).fit(X)
labels = gmm.predict(X)
labels
# Out:
# array([3, 3, 2, ..., 2, 2, 1])

# %%
list(X)
# Out:
# ['Smoking',
#  'Yellow_Fingers',
#  'Anxiety',
#  'Peer_Pressure',
#  'Genetics',
#  'Attention_Disorder',
#  'Born_an_Even_Day',
#  'Car_Accident',
#  'Fatigue',
#  'Allergy',
#  'Coughing',
#  'Lung_cancer']

# %%
X.shape
# Out:
# (2000, 12)

# %%
data_new = gmm.sample(200)
X_new = pd.DataFrame(data_new[0], columns=list(X))
X_new
# Out:
#       Smoking  Yellow_Fingers   Anxiety  Peer_Pressure  Genetics  \
# 0    1.024534        1.014499  1.106686       0.570671 -0.248094
# 1    0.983291        0.980557  0.806867       0.138881  0.215866
# 2    0.975121        0.975724  0.717177       0.983323  0.095882
# 3    0.997053        1.006147  0.744055       1.215868  0.460811
# 4    1.003604        1.004682  0.887397      -0.117375  1.079384
# ..        ...             ...       ...            ...       ...
# 195  0.941154        1.365814 -0.225996      -0.373215 -0.070222
# 196  0.976099        1.073352  1.253386      -0.580087 -0.102736
# 197  1.021754        1.024903  1.356943       0.182930  0.084493
# 198  1.022875        1.321027  0.773962      -0.287774 -0.160287
# 199  0.941069        0.999855  0.396001      -0.890852  0.000306
#
#      Attention_Disorder  Born_an_Even_Day  Car_Accident   Fatigue   Allergy  \
# 0             -0.128146          0.043002      0.883214  1.013521  0.628556
# 1              0.829756          0.075302      0.952496  0.968629  0.263043
# 2              0.719609         -0.464247      0.496127  0.992151  0.762626
# 3              0.467406         -0.010009      0.969777  0.997362  0.254489
# 4              1.353616          0.392226      0.790836  1.010704  0.424218
# ..                  ...               ...           ...       ...       ...
# 195            0.476673         -0.169257      0.958559  0.743609 -0.216595
# 196            0.008664          0.888981      1.026537  0.477464  0.118994
# 197            0.070997          1.030193      1.442338  1.099545 -0.332247
# 198           -0.035652          1.018546      0.761517 -0.616571  0.169810
# 199            1.008871          0.730152      1.432941  0.230172  0.019121
#
#      Coughing  Lung_cancer
# 0    1.525750     0.996880
# 1    1.028042     0.998725
# 2    1.077556     0.997988
# 3    1.389440     1.004164
# 4    1.003815     0.991414
# ..        ...          ...
# 195 -0.244137     0.312759
# 196 -0.206874     0.558252
# 197 -0.693025     0.059675
# 198 -0.399060     0.382938
# 199 -0.465679     0.410933
#
# [200 rows x 12 columns]

# %%
analysis_results2, summary2 = aitia_ex.run_analysis(X_new, target_graph_str=None, pc=pc)
summary2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f132417c12a5> in <module>
# ----> 1 analysis_results2, summary2 = aitia_ex.run_analysis(X_new, target_graph_str=None, pc=pc)
#       2 summary2
#
# NameError: name 'aitia_ex' is not defined

# %%
analysis_results[0]['causal_graph'].draw()
